# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## load the final_tmdb_data_2000.csv.gz display head
df0 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df0.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
## load the final_tmdb_data_2001.csv.gz display head
df1 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df1.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %%
frames = [df0, df1]
result = pd.concat(frames)
result.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
Fin_inf = result['revenue'] > 0

# %%
import operator 

Fin_inf = operator.or_(result['budget'] >0, result['revenue'] >0)

# %%
Fin_inf
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1294    False
# 1295    False
# 1296    False
# 1297    False
# 1298    False
# Length: 2518, dtype: bool

# %%
Fin_inf.value_counts()
# Out:
# False    1890
# True      628
# dtype: int64

# %%
result =result[Fin_inf]
result
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 6     tt0119273    0.0  /f5C03doOWiauu37bToKXtpgP5bS.jpg
# 10    tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 11    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# ...         ...    ...                               ...
# 1235  tt0445841    0.0  /lO3XAxV38SC7ZuuNVdy6E6nOZac.jpg
# 1251  tt0867181    0.0                               NaN
# 1253  tt1039952    0.0  /yTGmGjAd0gfpVK0ezoqWgx7AJkp.jpg
# 1266  tt1764172    0.0                               NaN
# 1278  tt2957918    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 1                                                   NaN  10000000.0
# 4                                                   NaN    150000.0
# 6     {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# ...

# %%
result['certification'].value_counts()
# Out:
# R        230
# PG-13    131
# PG        35
# NR        17
# G         14
# Name: certification, dtype: int64

# %%
categories = result['certification'].value_counts().plot.barh()
plt.title('categories')
# Out:
# Text(0.5, 1.0, 'categories')

# %%
categories = result['certification'].value_counts().plot.barh()
plt.title('categories')
# Out:
# Text(0.5, 1.0, 'categories')

# %%
 result.groupby('certification')['revenue'].mean().plot.barh()
# Out:
# <AxesSubplot: ylabel='certification'>

# %%
 result.groupby('certification')['budget'].mean().plot.barh()
# Out:
# <AxesSubplot: ylabel='certification'>

# %%
result.to_csv('Data/2000-1data.csv')
