# %% [markdown]
# Ahmad Almasri
#
# Project 3
# 01/27/2023

# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1948
# 1  tt0000002            5.8       264
# 2  tt0000003            6.5      1778
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2582

# %%
akas.replace({'\\N':np.nan},inplace=True)

# %% [markdown]
# Replace "\N" with np.nan

# %%
basics.replace({'\\N':np.nan},inplace=True)

# %% [markdown]
# Replace "\N" with np.nan

# %%
ratings.replace({'\\N':np.nan},inplace=True)

# %% [markdown]
# Replace "\N" with np.nan

# %%
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1292098
# endYear           9483757
# runtimeMinutes    6786079
# genres             433951
# dtype: int64

# %%
ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
akas.isna().sum()
# Out:
# titleId                   0
# ordering                  0
# title                     5
# region              1878699
# language            6489042
# types              29324853
# attributes         34530315
# isOriginalTitle        2109
# dtype: int64

# %%
basics.dropna(subset=['runtimeMinutes'], inplace=True)

# %% [markdown]
# Eliminate movies that are null for runtimeMinutes

# %%
basics.dropna(subset=['genres'], inplace=True)

# %% [markdown]
# Eliminate movies that are null for genre

# %%
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear          154945
# endYear           2676262
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2724348 entries, 0 to 9585853
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 207.9+ MB

# %%
basics['startYear'] = basics['startYear'].astype(float)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2724348 entries, 0 to 9585853
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       float64
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: float64(1), object(8)
# memory usage: 207.9+ MB

# %%
basics = basics[basics['startYear'] >= 2000]
basics
# Out:
#             tconst  titleType                    primaryTitle  \
# 13082    tt0013274      movie     Istoriya grazhdanskoy voyny
# 17928    tt0018190      short   Walking from Munich to Berlin
# 33803    tt0034413      short              Youth Gets a Break
# 34617    tt0035235      short                  Radio Dynamics
# 34803    tt0035423      movie                  Kate & Leopold
# ...            ...        ...                             ...
# 9585804  tt9916754      movie  Chico Albuquerque - Revelações
# 9585810  tt9916766  tvEpisode                  Episode #10.15
# 9585845  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9585852  tt9916856      short                        The Wind
# 9585853  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult  startYear endYear  \
# 13082       Istoriya grazhdanskoy voyny       0     2021.0     NaN
# 17928          München-Berlin Wanderung       0     2018.0     NaN
# 33803                Youth Gets a Break       0     2001.0     NaN
# 34617                    Radio Dynamics       0     2016.0     NaN
# 34803                    Kate & Leopold       0     2001.0     NaN
# ...                                 ...     ...        ...     ...
# 9585804  Chico Albuquerque - Revelações       0     2013.0     NaN
# 9585810                  Episode #10.15       0     2019.0     NaN
# 9585845      Horrid Henry's Comic Caper       0     2014.0     NaN
# 9585852                        The Wind       0     2015.0     NaN
# 9585853       Horrid Henry Knows It All       0     2014.0     NaN
#
#         runtimeMinutes                       genres
# 13082              133                  Documentary
# 17928                3                        Short
# 33803               20                        Short
# 34617                4                        Short
# 34803              118       Comedy,Fantasy,Romance
# ...                ...                          ...
# 9585804             49                  Documentary
# 9585810             43  Family,Game-Show,Reality-TV
# 9585845             11   Adventure,Animation,Comedy
# 9585852             27                        Short
# 9585853             10   Adventure,Animation,Comedy
#
# [1889090 rows x 9 columns]

# %% [markdown]
# keep startYear 2000-2022

# %%
is_movie = basics['titleType'] == 'movie'
basics = basics[is_movie]
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 76059    tt0077684     movie
# ...            ...       ...
# 9585620  tt9916362     movie
# 9585704  tt9916538     movie
# 9585745  tt9916622     movie
# 9585772  tt9916680     movie
# 9585804  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 76059                    Histórias de Combóios em Portugal
# ...                                                    ...
# 9585620                                              Coven
# 9585704                                Kuambil Lagi Hatiku
# 9585745        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9585772  De la ilusión al desconcierto: cine colombiano...
# 9585804                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El tango del viudo y su espejo deformante       0     2020.0
# 67669                           The Other Side of the Wind       0     2018.0
# 76059                    Histórias de Combóios em Portugal       0     2022.0
# ...                                                    ...     ...        ...
# 9585620                                           Akelarre       0     2020.0
# 9585704                                Kuambil Lagi Hatiku       0     2019.0
# 9585745        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9585772  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9585804                     Chico Albuquerque - Revelações       0     2013.0
#
#         endYear runtimeMinutes                  genres
# 13082       NaN            133             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 67669       NaN            122                   Drama
# 76059       NaN             46             Documentary
# ...         ...            ...                     ...
# 9585620     NaN             92           Drama,History
# 9585704     NaN            123                   Drama
# 9585745     NaN             57             Documentary
# 9585772     NaN            100             Documentary
# 9585804     NaN             49             Documentary
#
# [223078 rows x 9 columns]

# %% [markdown]
# keep only titleType==Movie

# %%
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %% [markdown]
# Eliminate movies that include "Documentary"

# %%
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 34784265  tt9916852         5             Episódio #3.20     PT       pt
# 34784266  tt9916852         6             Episodio #3.20     IT       it
# 34784267  tt9916852         7               एपिसोड #3.20     IN       hi
# 34784268  tt9916856         1                   The Wind     DE      NaN
# 34784269  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 34784265          NaN            NaN               0
# 34784266          NaN            NaN               0
# 34784267          NaN            NaN               0
# 34784268  imdbDisplay            NaN               0
# 34784269     original            NaN               1
#
# [34784270 rows x 8 columns]

# %%
akas  = akas[akas['region'] == 'US']
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 34783797  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 34783867  tt9916620         1                          The Copeland Case
# 34783955  tt9916702         1              Loving London: The Playground
# 34783998  tt9916756         1                   Pretty Pretty Black Girl
# 34784014  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 34783797     US      NaN  imdbDisplay                    NaN               0
# 34783867     US      NaN          NaN                    NaN               0
# 34783955     US      NaN          NaN                    NaN               0
# 34783998     US      NaN  imdbDisplay                    NaN               0
# 34784014     US      NaN  imdbDisplay                    NaN               0
#
# [1411159 rows x 8 columns]

# %%
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803       True
# 61116       True
# 67669       True
# 77964      False
# 86801       True
#            ...
# 9585527     True
# 9585536     True
# 9585575    False
# 9585620     True
# 9585704    False
# Name: tconst, Length: 147693, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9584991  tt9914942     movie
# 9585387  tt9915872     movie
# 9585527  tt9916170     movie
# 9585536  tt9916190     movie
# 9585620  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9584991                             Life Without Sara Amat
# 9585387                               The Last White Witch
# 9585527                                      The Rehearsal
# 9585536                                          Safeguard
# 9585620                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0     2001.0     NaN
# 61116    El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67669                   The Other Side of the Wind       0     2018.0     NaN
# 86801                            The Naked Monster       0     2005.0     NaN
# 93938                         Crime and Punishment       0     2002.0     NaN
# ...                                            ...     ...        ...     ...
# 9584991                 La vida sense la Sara Amat       0     2019.0     NaN
# 9585387                  My Girlfriend is a Wizard       0     2019.0     NaN
# 9585527                                   O Ensaio       0     2019.0     NaN
# 9585536                                  Safeguard       0     2020.0     NaN
# 9585620                                   Akelarre       0     2020.0     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9584991             74                      Drama
# 9585387             97       Comedy,Drama,Fantasy
# 9585527             51                      Drama
# 9585536             95  Action,Adventure,Thriller
# 9585620             92              Drama,History
#
# [85531 rows x 9 columns]

# %% [markdown]
# Keep only US movies

# %%
count_row = basics.shape[0] 
count_row
# Out:
# 85531

# %%
keepers =ratings['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1275127    False
# 1275128    False
# 1275129    False
# 1275130    False
# 1275131    False
# Name: tconst, Length: 1275132, dtype: bool

# %%
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1948
# 1        tt0000002            5.8       264
# 4        tt0000005            6.2      2582
# 5        tt0000006            5.1       177
# 6        tt0000007            5.4       810
# ...            ...            ...       ...
# 1275099  tt9916200            8.2       220
# 1275100  tt9916204            8.2       251
# 1275107  tt9916348            8.5        17
# 1275108  tt9916362            6.4      5162
# 1275112  tt9916428            3.8        14
#
# [487385 rows x 3 columns]

# %% [markdown]
# Keep only US movies

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1948
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2582
# 3  tt0000006            5.1       177
# 4  tt0000007            5.4       810

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
# Additional Imports
import os, json, math, time
from tqdm.notebook import tqdm_notebook

with open('/Users/Zofo/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['API Key'])

# %%
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in c:\users\zofo\anaconda3\envs\dojo-env\lib\site-packages (2.9.1)
# Requirement already satisfied: requests in c:\users\zofo\anaconda3\envs\dojo-env\lib\site-packages (from tmdbsimple) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\zofo\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zofo\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zofo\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\zofo\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (1.26.13)

# %%
import tmdbsimple as tmdb
# Instantiate tmdbapi Variable
tmdb.API_KEY =  login['API Key']

# %%
## make a movie object using the .Movies function from tmdb
movie = tmdb.Movies(603)

# %%
## movie objects have a .info dictionary 
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/waCRuAW5ocONRehP556vPexVXA9.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 83.983,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/tXMFoE8AtNdnFzWOW0aCLwl7xxS.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.196,
#  'vote_count': 22753}

# %%
info['budget']
# Out:
# 63000000

# %%
info['revenue']
# Out:
# 463517383

# %%
info['imdb_id']
# Out:
# 'tt0133093'

# %%
movie = tmdb.Movies('tt1361336')
info = movie.info()
info['budget']
# Out:
# 50000000

# %%
# example from package README
# source = https://github.com/celiao/tmdbsimple
releases = movie.releases()
for c in releases['countries']:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
# Out:
# PG
# PG
# PG

# %%
# Get the movie object for the current id
movie = tmdb.Movies('tt1361336')
# save the .info .releases dictionaries
info = movie.info()
releases = movie.releases()
# Loop through countries in releases
for c in releases['countries']:
    # if the country abbreviation==US
    if c['iso_3166_1' ] =='US':
        ## save a "certification" key in the info dict with the certification
       info['certification'] = c['certification']

# %%
def get_movie_with_rating(movie_id):
    ## Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    
    ##save the  .info .releases dictionaries
    info = movie.info()
    releases = movie.releases()
    ## loop through countries in releses
    for c in releases['countries']:
        # if the country abbreviation==US
        if c['iso_3166_1'] == 'US':
            ## save a certifcation key in info with the certication
            info['certification'] = c['certification']
    return info

# %%
test = get_movie_with_rating("tt0848228") #put your function name here
test
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 132.528,
#  'poster_path': '/tYqp6vEOo8YlVWrYQvt9nyOhsA2.jpg',
#  'production_companies': [{'id': 420,
#    'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#    'name': 'Marvel Studios',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2012-04-25',
#  'revenue': 1518815515,
#  'runtime': 143,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#   {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'Some assembly required.',
#  'title': 'The Avengers',
#  'video': False,
#  'vote_average': 7.707,
#  'vote_count': 28139,
#  'certification': 'PG-13'}

# %%
## testing our function by looping through a list of ids
import pandas as pd
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except: 
        pass
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
#   original_language original_title  ...     revenue  runtime  \
# 0                en   The Avengers  ...  1518815515      143
# 1                en   The Avengers  ...  1518815515      143
# 2                en   The Notebook  ...   115603229      123
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline         title  video  \
# 0                    Some assembly required.  The Avengers  False
# 1                    Some assembly required.  The Avengers  False
# 2  Behind every great love is a great story.  The Notebook  False
#
#    vote_average vote_count certification
# 0         7.707      28139         PG-13
# 1         7.707      28139         PG-13
# 2         7.879      10120         PG-13
#
# [3 rows x 26 columns]

# %%
## testing our function by looping through a list of ids
import pandas as pd
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
errors = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except Exception as e: 
        errors.append([movie_id, e])
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
#   original_language original_title  ...     revenue  runtime  \
# 0                en   The Avengers  ...  1518815515      143
# 1                en   The Avengers  ...  1518815515      143
# 2                en   The Notebook  ...   115603229      123
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline         title  video  \
# 0                    Some assembly required.  The Avengers  False
# 1                    Some assembly required.  The Avengers  False
# 2  Behind every great love is a great story.  The Notebook  False
#
#    vote_average vote_count certification
# 0         7.707      28139         PG-13
# 1         7.707      28139         PG-13
# 2         7.879      10120         PG-13
#
# [3 rows x 26 columns]

# %%
print(f"- Number of errors: {len(errors)}")
errors
# Out:
# - Number of errors: 1
# [['tt0115937',
#   requests.exceptions.HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0115937?api_key=8a3853f8dbcec3a3dbf8eb2fd9d542e5')]]

# %%
import os, time,json
import tmdbsimple as tmdb 
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['title_akas.csv.gz', 'title_basics.csv.gz', 'title_ratings.csv.gz']

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
 YEARS_TO_GET = [2000,2001]

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
        #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    
            # If it does not exist: create it
    if file_exists == False:
    # save an empty dict with just "imdb_id" to the new json file.
      with open(JSON_FILE,'w') as f:
        json.dump([{'imdb_id':0}],f)
        #Saving new year as the current df
    df = basics.loc[ basics['startYear']==YEAR].copy()
    # saving movie ids to list
    movie_ids = df['tconst'].copy()
            # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

            #saving new year as the current df
    df = basics.loc[ basics['startYear']== YEAR].copy()

            #saving movie ids to list
    movie_ids = df['tconst'].copy()# .to_list
    movie_ids
            # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)
    previous_df

            # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

            #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)

        except Exception as e:
            errors.append([movie_id, e])

        final_year_df = pd.read_json(JSON_FILE)
        final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/1142 [00:00<?, ?it/s]
# Movies from 2001:   0%|          | 0/1543 [00:00<?, ?it/s]
