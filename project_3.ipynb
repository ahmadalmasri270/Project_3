# %% [markdown]
# Ahmad Almasri
#
# Project 3
# 01/27/2023

# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1948
# 1  tt0000002            5.8       264
# 2  tt0000003            6.5      1774
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2581

# %%
akas.replace({'\\N':np.nan},inplace=True)

# %% [markdown]
# Replace "\N" with np.nan

# %%
basics.replace({'\\N':np.nan},inplace=True)

# %% [markdown]
# Replace "\N" with np.nan

# %%
ratings.replace({'\\N':np.nan},inplace=True)

# %% [markdown]
# Replace "\N" with np.nan

# %%
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1289380
# endYear           9472338
# runtimeMinutes    6785632
# genres             434348
# dtype: int64

# %%
ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
akas.isna().sum()
# Out:
# titleId                   0
# ordering                  0
# title                     5
# region              1878210
# language            6485558
# types              29293687
# attributes         34496230
# isOriginalTitle        2109
# dtype: int64

# %%
basics.dropna(subset=['runtimeMinutes'], inplace=True)

# %% [markdown]
# Eliminate movies that are null for runtimeMinutes

# %%
basics.dropna(subset=['genres'], inplace=True)

# %% [markdown]
# Eliminate movies that are null for genre

# %%
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 1
# startYear          154303
# endYear           2739042
# runtimeMinutes          0
# genres              75380
# dtype: int64

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2788625 entries, 0 to 9574256
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 212.8+ MB

# %%
basics['startYear'] = basics['startYear'].astype(float)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2788625 entries, 0 to 9574256
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       float64
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: float64(1), object(8)
# memory usage: 212.8+ MB

# %%
basics = basics[basics['startYear'] >= 2000]
basics
# Out:
#             tconst  titleType                    primaryTitle  \
# 13082    tt0013274      movie     Istoriya grazhdanskoy voyny
# 15178    tt0015414      movie          La tierra de los toros
# 17928    tt0018190      short   Walking from Munich to Berlin
# 33803    tt0034413      short              Youth Gets a Break
# 34617    tt0035235      short                  Radio Dynamics
# ...            ...        ...                             ...
# 9574207  tt9916754      movie  Chico Albuquerque - Revelações
# 9574213  tt9916766  tvEpisode                  Episode #10.15
# 9574248  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9574255  tt9916856      short                        The Wind
# 9574256  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult  startYear endYear  \
# 13082       Istoriya grazhdanskoy voyny       0     2021.0     NaN
# 15178            La tierra de los toros       0     2000.0     NaN
# 17928          München-Berlin Wanderung       0     2018.0     NaN
# 33803                Youth Gets a Break       0     2001.0     NaN
# 34617                    Radio Dynamics       0     2016.0     NaN
# ...                                 ...     ...        ...     ...
# 9574207  Chico Albuquerque - Revelações       0     2013.0     NaN
# 9574213                  Episode #10.15       0     2019.0     NaN
# 9574248      Horrid Henry's Comic Caper       0     2014.0     NaN
# 9574255                        The Wind       0     2015.0     NaN
# 9574256       Horrid Henry Knows It All       0     2014.0     NaN
#
#         runtimeMinutes                       genres
# 13082              133                  Documentary
# 15178               60                          NaN
# 17928                3                        Short
# 33803               20                        Short
# 34617                4                        Short
# ...                ...                          ...
# 9574207             49                  Documentary
# 9574213             43  Family,Game-Show,Reality-TV
# 9574248             11   Adventure,Animation,Comedy
# 9574255             27                        Short
# 9574256             10   Adventure,Animation,Comedy
#
# [1919560 rows x 9 columns]

# %% [markdown]
# keep startYear 2000-2022

# %%
is_movie = basics['titleType'].str.contains('movie',case=False)
basics = basics[is_movie]
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 15178    tt0015414     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# ...            ...       ...
# 9574148  tt9916622     movie
# 9574175  tt9916680     movie
# 9574180  tt9916692   tvMovie
# 9574197  tt9916730     movie
# 9574207  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 15178                               La tierra de los toros
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# ...                                                    ...
# 9574148        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9574175  De la ilusión al desconcierto: cine colombiano...
# 9574180                    Teatroteka: Czlowiek bez twarzy
# 9574197                                             6 Gunn
# 9574207                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 15178                               La tierra de los toros       0     2000.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El tango del viudo y su espejo deformante       0     2020.0
# 67669                           The Other Side of the Wind       0     2018.0
# ...                                                    ...     ...        ...
# 9574148        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9574175  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9574180                    Teatroteka: Czlowiek bez twarzy       0     2015.0
# 9574197                                             6 Gunn       0     2017.0
# 9574207                     Chico Albuquerque - Revelações       0     2013.0
#
#         endYear runtimeMinutes                  genres
# 13082       NaN            133             Documentary
# 15178       NaN             60                     NaN
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 67669       NaN            122                   Drama
# ...         ...            ...                     ...
# 9574148     NaN             57             Documentary
# 9574175     NaN            100             Documentary
# 9574180     NaN             66                   Drama
# 9574197     NaN            116                     NaN
# 9574207     NaN             49             Documentary
#
# [277900 rows x 9 columns]

# %% [markdown]
# keep only titleType==Movie

# %%
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %% [markdown]
# Eliminate movies that include "Documentary"

# %%
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 34749979  tt9916852         5             Episódio #3.20     PT       pt
# 34749980  tt9916852         6             Episodio #3.20     IT       it
# 34749981  tt9916852         7               एपिसोड #3.20     IN       hi
# 34749982  tt9916856         1                   The Wind     DE      NaN
# 34749983  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 34749979          NaN            NaN               0
# 34749980          NaN            NaN               0
# 34749981          NaN            NaN               0
# 34749982  imdbDisplay            NaN               0
# 34749983     original            NaN               1
#
# [34749984 rows x 8 columns]

# %%
akas  = akas[akas['region'] == 'US']
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 34749511  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 34749581  tt9916620         1                          The Copeland Case
# 34749669  tt9916702         1              Loving London: The Playground
# 34749712  tt9916756         1                   Pretty Pretty Black Girl
# 34749728  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 34749511     US      NaN  imdbDisplay                    NaN               0
# 34749581     US      NaN          NaN                    NaN               0
# 34749669     US      NaN          NaN                    NaN               0
# 34749712     US      NaN  imdbDisplay                    NaN               0
# 34749728     US      NaN  imdbDisplay                    NaN               0
#
# [1410127 rows x 8 columns]

# %%
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 13082      False
# 15178      False
# 34803       True
# 61116       True
# 67669       True
#            ...
# 9574148    False
# 9574175    False
# 9574180    False
# 9574197    False
# 9574207    False
# Name: tconst, Length: 277900, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9573611  tt9915436     movie
# 9573790  tt9915872     movie
# 9573930  tt9916170     movie
# 9573939  tt9916190     movie
# 9574023  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9573611                                  Vida em Movimento
# 9573790                               The Last White Witch
# 9573930                                      The Rehearsal
# 9573939                                          Safeguard
# 9574023                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0     2001.0     NaN
# 61116    El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67669                   The Other Side of the Wind       0     2018.0     NaN
# 86801                            The Naked Monster       0     2005.0     NaN
# 93938                         Crime and Punishment       0     2002.0     NaN
# ...                                            ...     ...        ...     ...
# 9573611                          Vida em Movimento       0     2019.0     NaN
# 9573790                  My Girlfriend is a Wizard       0     2019.0     NaN
# 9573930                                   O Ensaio       0     2019.0     NaN
# 9573939                                  Safeguard       0     2020.0     NaN
# 9574023                                   Akelarre       0     2020.0     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9573611             70                Documentary
# 9573790             97       Comedy,Drama,Fantasy
# 9573930             51                      Drama
# 9573939             95  Action,Adventure,Thriller
# 9574023             92              Drama,History
#
# [135715 rows x 9 columns]

# %% [markdown]
# Keep only US movies

# %%
count_row = basics.shape[0] 
count_row
# Out:
# 167559

# %%
keepers =ratings['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1274329    False
# 1274330    False
# 1274331    False
# 1274332    False
# 1274333    False
# Name: tconst, Length: 1274334, dtype: bool

# %%
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1948
# 1        tt0000002            5.8       264
# 4        tt0000005            6.2      2581
# 5        tt0000006            5.1       177
# 6        tt0000007            5.4       810
# ...            ...            ...       ...
# 1274301  tt9916200            8.2       220
# 1274302  tt9916204            8.2       251
# 1274309  tt9916348            8.5        17
# 1274310  tt9916362            6.4      5153
# 1274314  tt9916428            3.8        14
#
# [486920 rows x 3 columns]

# %% [markdown]
# Keep only US movies

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1948
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2581
# 3  tt0000006            5.1       177
# 4  tt0000007            5.4       810

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0
